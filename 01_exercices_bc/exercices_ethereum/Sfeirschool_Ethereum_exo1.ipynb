// %% [markdown]
// <img src="logo.svg" style="padding-top:30px">
//
// <h1> SfeirSchool Blockchain - ETHEREUM - </h1>
// <h3> <b>Exercice 1</b> : <i>Configure Development Environment</i></h3>
// <p style="padding-top: 20px">
// <code>Objective</code> : Configure an ethereum environment in using docker and docker-compose.
// </p>
// <div class="alert alert-block alert-info">
// <h4> <b>Step 1</b></h4>
// <p style="padding-top: 20px">
// <code>Objective</code> :  run docker images with Ganache and Truffle.
//
// (requirement: docker, docker-compose)
//
// <lu>
//     <li><b style="color:blue">(1)</b> Open a terminal</li>
//     <li><b style="color:blue">(2)</b> Go to <b style="color:black">/04_ethereum/ </b> directory</li>
//     <li><b style="color:blue">(3)</b> Execute <b style="color:black">'docker-compose up -d --remove-orphan'</b> command</li>
//     <li><b style="color:blue">(4)</b> Check that Dockerfile file for must be properly build, as presented below: <img src="cmd-exec-dockerfile-truffleapp-build.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(5)</b> Execute <b style="color:black">'docker ps'</b> command. Verify that <b style="color:black">'truffle-app'</b> and <b style="color:black">'ganache-cli'</b> containers have been started.
//      <img src="cmd-docker-ps-running-containers.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
// </lu>
//
//
// <code>Notes</code> :
// <lu>
//     <li><b style="color:green">Ganache</b>:
//      dsdqs
//     </li>
//     <li><b style="color:green">Truffle</b>:
//       sdsd
//     </li>
// </lu>
// </p>
// </div>

// %% [markdown]
// <div class="alert alert-block alert-info">
// <h4> <b>Step 2</b></h4>
// <p style="padding-top: 20px">
// <code>Objective</code> :  Discover ethereum local network.
//
// <lu>
//     <li><b style="color:blue">(1)</b> Execute <b style="color:black">'docker logs ganache-cli'</b> command</li>
//     <li><b style="color:blue">(2)</b> Find accounts :
//     <img src="eth_accounts.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(3)</b> Find private keys :
//     <img src="eth_private-key.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(4)</b> <b>How much is Gas Price ?</b>
//     </li>
//
// </lu>

// %% [markdown]
// <div class="alert alert-block alert-info">
// <h4> <b>Step 3</b></h4>
// <p style="padding-top: 20px">
// <code>Objective</code> :  Truffle environement.
//
// <ul>
//     <li><b style="color:blue">(1)</b> Execute <b style="color:black">'docker exec -it truffle-app bash'</b> command</li>
//     <li><b style="color:blue">(2)</b> Execute <b style="color:black">'ls -l'</b> command
//     <img src="cmd-metacoin-ls-l.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(3)</b> Directory description :
//         <ul style="list-style-type:none;">
//             <li><b style="color:yellow">contracts</b> Contain the list of contracts. (extension *.sol : solidity)</li>
//             <li><b style="color:yellow">migrations</b> Scripting for deployment</li>
//             <li><b style="color:yellow">tests</b> Tests for contracts</li>
//             <li><b style="color:yellow">truffle-config.js</b> Configuration with ethereum networks</li>
//         </ul>
//     </li>
// </ul>

// %% [markdown]
// <div class="alert alert-block alert-info">
// <h4> <b>Step 3</b></h4>
// <p style="padding-top: 20px">
// <code>Objective</code> :  Discover the MetaCoin contract.
//
// <ul>
//     <li><b style="color:blue">(1)</b> Contract is located on <b>./contract/MetaCoin.sol</b></li>
//     <li><b style="color:blue">(2)</b> Solidity file contains:
//         <ul style="list-style-type:none;">
//             <li><b style="color:yellow">version</b>  ex: 'pragma solidity >=0.4.25'</li>
//             <li><b style="color:yellow">import from other contract/file</b>  import "./ConvertLib.sol";</li>
//             <li><b style="color:yellow">contract</b>   ex: 'contract MetaCoin { ... }'</li>
//             <li><b style="color:yellow">some function, which will be called by ethereum transactions</b>  <br> ex: 'function sendCoin(address receiver, uint amount) public returns(bool sufficient)'</li>
//         </ul>
//     </li>
//     <li><b style="color:blue">(3)</b> What is contract doing ?
//       <ul style="list-style-type:square;">
//           <li><i>'sendCoin(...)'</i> : Send ETH from </li>
//           <li><i>'sendCoin(...)'</i> : Send ETH from </li>
//           <li><i>'sendCoin(...)'</i> : Send ETH from </li>
//       </ul>
//     </li>
//     <li><b style="color:blue">(4)</b> Test MetaCoin contract <b style="color:black">'truffle test ./test/TestMetacoin.sol'</b> command
//         <img src="cmd-test-metacoin.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(5)</b> Deploy contract with <b style="color:black">'truffle migrate'</b> command
//         <img src="cmd-truffle-migrate.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(6)</b> Using contract, execute <b style="color:black">'truffle console development'</b> command
//         <img src="cmd-truffle-console.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(7)</b> List account <b style="color:black">'let account = web3.eth.accounts'</b> command
//         <img src="cmd-truffle-list-account.png" style="padding-top:10px;padding-bottom:20px">
//     </li>
//     <li><b style="color:blue">(8)</b> Find balance for account n°0 in using MetaCoin contract <b style="color:black">
//        <pre><code>
//             MetaCoin.deployed()
//                 .then(function(instance){
//                     return instance.getBalance(account[0]);
//                  }).then(function(result){
//                     return console.log("balance: "+result);
//                  });
//         </code></pre><img src="cmd_truffle-getbalance.png" style="padding-top:10px;padding-bottom:20px"></img><i style="color:yellow">Trying yourself to find other balance accounts.</i>
//         </li>
//     <li><b style="color:blue">(9)</b> Transfer amount between two account in using MetaCoin contract <b style="color:black">
//        <pre><code>
//             [1] MetaCoin.deployed()
//                 .then(function(instance){
//                     return instance.sendCoin(account[1], 2);
//                  });
//             [2] MetaCoin.deployed()
//                 .then(function(result){
//                     return instance.getBalance(account[1]);
//                  }).then(function(result){
//                     return console.log("balance: "+result);
//                  });
//         </code></pre> <i style="color:yellow">[1] send coins to account n°1. [2] get balance of account n°1</i>
//         <img src="cmd-truffle-sendcoin.png" style="padding-top:10px;padding-bottom:20px"></img>
//         </li>
// </ul>
